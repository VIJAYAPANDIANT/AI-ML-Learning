# %% [markdown]
# <a href="https://colab.research.google.com/github/VIJAYAPANDIANT/AI-ML-Learning/blob/main/01_numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers*2)
# Out:
# [ 20  40  60  80 100]
